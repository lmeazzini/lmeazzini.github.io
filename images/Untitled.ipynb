# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img = cv.imread('rome.JPG')
img = img[:,:,::-1]

# %%
img.shape
# Out:
# (3072, 4608, 3)

# %%
plt.imshow(img[1350:2650,700:3900])

# %%
img = img[1350:2650,700:3900]

# %%
img = cv.resize(img, (1640, 512))

# %%
cv.imwrite('rome_resize.jpg',img[:,:,::-1])
# Out:
# True

# %%
img2 = cv.imread('waterfront.jpg')

# %%
img2.shape
# Out:
# (812, 2048, 3)
